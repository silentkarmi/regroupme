# %%
#********************************************************************************************
# reference code for naive bayes for yes or now :
# https://www.analyticsvidhya.com/blog/2021/01/a-guide-to-the-naive-bayes-algorithm/
# https://code.visualstudio.com/docs/datascience/data-science-tutorial
#
# All other stuff in the code to associate them into groups and print them by Kartikeya Mishra
#********************************************************************************************

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('data_set.csv')
X = dataset.iloc[:, [2, 3]].values
y = dataset.iloc[:, -1].values

print(X)
print(y)
# Out:
# [[179.         169.        ]
#  [163.83        54.87528345]
#  [164.         150.        ]
#  [175.         139.        ]
#  [188.         177.        ]
#  [171.45        58.9569161 ]
#  [177.8         57.14285714]
#  [205.74        97.50566893]
#  [185.         139.        ]
#  [187.96        77.09750567]
#  [177.         110.        ]
#  [182.88        72.10884354]
#  [203.2         94.33106576]
#  [188.         135.        ]
#  [180.         117.        ]
#  [203.         233.        ]
#  [168.91        58.9569161 ]
#  [177.         132.        ]
#  [210.82       113.37868481]
#  [165.1         58.04988662]
#  [181.         135.        ]
#  [167.64        57.14285714]
#  [203.2        102.04081633]
#  [180.         134.        ]
#  [176.         142.        ]
#  [200.66       107.93650794]
#  [193.04        84.80725624]
#  [182.88        81.17913832]
#  [172.72        63.94557823]
#  [192.         184.        ]
#  [170.18        59.86394558]
#  [181.         151.        ]
# ...

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

X_test_before_scaling = X_test 

print((X_test))
print((y_test))
# Out:
# [[185.42        88.88888889]
#  [186.         137.        ]
#  [188.         139.        ]
#  [185.         139.        ]
#  [180.34        68.02721088]
#  [203.2        102.04081633]
#  [205.74        97.50566893]
#  [177.         110.        ]
#  [183.         127.        ]
#  [193.04        89.79591837]
#  [168.91        53.96825397]
#  [185.         143.        ]
#  [164.         150.        ]
#  [213.36       122.44897959]
#  [195.58        97.50566893]
#  [200.66        97.50566893]
#  [170.18        59.86394558]
#  [165.1         53.96825397]
#  [180.34        82.99319728]
#  [200.66        92.5170068 ]
#  [195.58        82.0861678 ]
#  [189.         143.        ]
#  [168.91        58.9569161 ]
#  [176.         142.        ]]
# [2 3 3 3 1 2 2 3 3 2 1 3 3 2 2 2 1 1 2 2 2 3 1 3]

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Training the Naive Bayes model on the Training set
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# Predicting the Test set results
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)

ac = accuracy_score(y_test,y_pred)

print(ac)
# print(X_test_before_scaling)
# print(y_pred)
# print(y_test)
# Out:
# 0.9166666666666666

# %%
import itertools 

dataset = pd.read_csv('unseen_data_set.csv')
names = dataset.iloc[:,[1]].values
regroup_pending = dataset.iloc[:, [2, 3]].values

# print(names)
# print(regroup_pending)

regroup_pending = sc.transform(regroup_pending)
group_results = classifier.predict(regroup_pending)

marathoners = []
basketeer = []
yokozunas = []

itr = 0
for group in group_results:
    group = int(group)
    name = names[itr][0]
    # print(name)
    if group == 1:
        marathoners.append(name)
    elif group == 2:
        basketeer.append(name)
    else:
        yokozunas.append(name)
    
    itr += 1

header = []
header.append("Marathoners")
header.append("Basketeers")
header.append("Yokozunas")
print("="*90)
print (" ".join((word).ljust(col_width) for word in header))
print("="*90)


for (a, b, c) in itertools.zip_longest(marathoners, basketeer, yokozunas, fillvalue=" "):
    row = []
    row.append(a)
    row.append(b)
    row.append(c)
    col_width =  30# padding
    print (" ".join((word).ljust(col_width) for word in row))
# Out:
# ...
# Marathoners                    Basketeers                     Yokozunas
# ...
# Stefano Baldini (Italy)        DavisBertans                   Kotozakura
# Stephen Kiprotich (Uganda)     KeitaBates-Diop                Azumafuji
# Josia Thugwane (South Africa)  AdonisArms                     PatrickBeverley
#                                KhemBirch                      Konishiki
#                                GogaBitadze                    Tanikaze
#                                OchaiAgbaji                    Futabayama
#                                LonzoBall                      Hakuho
#                                StevenAdams                    Miyagiyama
#                                NicolasBatum                   Tachiyama
#                                                               Onomatsu
#                                                               Kagamisato
#                                                               Wakanohana II
# ...

# %%
# 1 - Elite Marathoners 
# 2 - NBA Players
# 3 - Yokozuna

# %%
import itertools 

dataset = pd.read_csv('class_experiment.csv')
names = dataset.iloc[:,[1]].values
regroup_pending = dataset.iloc[:, [2, 3]].values

# print(names)
# print(regroup_pending)

regroup_pending = sc.transform(regroup_pending)
group_results = classifier.predict(regroup_pending)

marathoners = []
basketeer = []
yokozunas = []

itr = 0
for group in group_results:
    group = int(group)
    name = names[itr][0]
    # print(name)
    if group == 1:
        marathoners.append(name)
    elif group == 2:
        basketeer.append(name)
    else:
        yokozunas.append(name)
    
    itr += 1

header = []
header.append("Marathoners")
header.append("Basketeers")
header.append("Yokozunas")
print("="*90)
print (" ".join((word).ljust(col_width) for word in header))
print("="*90)


for (a, b, c) in itertools.zip_longest(marathoners, basketeer, yokozunas, fillvalue=" "):
    row = []
    row.append(a)
    row.append(b)
    row.append(c)
    col_width =  30# padding
    print (" ".join((word).ljust(col_width) for word in row))
# Out:
# ...
# Marathoners                    Basketeers                     Yokozunas
# ...
#                                Y                              Kartikeya Mishra
#                                                               X
